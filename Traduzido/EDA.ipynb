# %%
from library import *
# Out:
# Using TensorFlow backend.

# %%
P = np.loadtxt('P_PY3D.csv')
T = np.asarray(np.loadtxt('T_PY.csv'))

# %%
P = P.reshape(4,10,P.shape[1])

# %%
P.shape
# Out:
# (4, 10, 119)

# %%
for i in range(10):
    fig, axs = plt.subplots(3,2)
    (ax1,ax2),(ax3,ax4),(ax5,ax6) = axs
    ax1.plot(P[0,i,:],P[1,i,:],'b.')
    ax2.plot(P[0,i,:],P[2,i,:],'b.')
    ax3.plot(P[0,i,:],P[3,i,:],'b.')
    ax4.plot(P[1,i,:],P[2,i,:],'b.')
    ax5.plot(P[1,i,:],P[3,i,:],'b.')
    ax6.plot(P[2,i,:],P[3,i,:],'b.')
