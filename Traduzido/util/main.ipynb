# %% [markdown]
# <h1><center>Unique and complete pipeline</center>
# <h3> On this notebook all the pipeline will be available. All the functions will be called from allFunction.py and the initial settings will be defined here.

# %%
from allFunctions import *
# Out:
# Using TensorFlow backend.

# %%
from settings import *

# %%
dataFinal
# Out:
# '09/03/2012 23:30:00'

# %%
downloadImagens(url, pathMag, dataInicial, dataFinal, resolucao, sufixoMag)
# Out:
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_000000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_003000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_010000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_013000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_020000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_023000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_030000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_033000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_040000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_043000_M_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\mag\20120307_050000_M_1k.jpg- arquivo já existente!
# ...

# %%
downloadImagens(url, pathContinua, dataInicial, dataFinal, resolucao, sufixoContinua)
# Out:
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_000000_Ic_flat_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_003000_Ic_flat_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_010000_Ic_flat_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_013000_Ic_flat_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_020000_Ic_flat_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_023000_Ic_flat_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_030000_Ic_flat_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_033000_Ic_flat_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_040000_Ic_flat_1k.jpg- arquivo já existente!
# D:\Amita\Doutorado\Tese\Traduzido\continuum\20120307_043000_Ic_flat_1k.jpg- arquivo já existente!
# ...

# %%
alpha_mu_spot, area_c, time = imagesMasks(path, dataInicial, dataFinal, resolucao)
# Out:
# Processando dia 2012-03-07 00:00:00
# C:\Users\Ami\Dropbox\Tese\Traduzido\util\allFunctions.py:450: RuntimeWarning: invalid value encountered in greater
#   bw4 = np.uint8(bw3 & (mu_rings > 0))
# C:\Users\Ami\Dropbox\Tese\Traduzido\util\allFunctions.py:530: RuntimeWarning: invalid value encountered in greater
#   bw_mask[np.where(mu_rings > 0)] = 1
# Processando dia 2012-03-07 00:30:00
#
# Processando dia 2012-03-07 06:00:00
#
# Processando dia 2012-03-07 06:30:00
#
# Processando dia 2012-03-07 12:00:00
#
# Processando dia 2012-03-07 12:30:00
#
# Processando dia 2012-03-07 18:00:00
#
# Processando dia 2012-03-07 18:30:00
#
# Processando dia 2012-03-08 00:00:00
#
# Processando dia 2012-03-08 00:30:00
#
# Processando dia 2012-03-08 06:00:00
#
# Processando dia 2012-03-08 06:30:00
#
# Processando dia 2012-03-08 12:00:00
#
# Processando dia 2012-03-08 12:30:00
#
# Processando dia 2012-03-08 18:00:00
#
# Processando dia 2012-03-08 18:30:00
#
# Processando dia 2012-03-09 00:00:00
#
# ...

# %%
model_mdi_02_03(path, dataInicial, dataFinal)
